# %% [markdown]
# # Predictive Uncertainty Estimation using Deep Ensemble (Regression)
#
# ## Dataset: Real dataset (Concrete Compressive Strength Dataset)
#
# This algorithm is implementation of paper [Simple and Scalable Predictive Uncertainty Estimation using Deep Ensembles](https://arxiv.org/abs/1612.01474). In this jupyter notebook, I will implement regression part of this paper using [Concrete Compressive Strength Dataset](https://archive.ics.uci.edu/ml/datasets/Concrete+Compressive+Strength)
# **5 networks** will be used for ensemble

# %% [markdown]
# ## Import Modules

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas

# %% [markdown]
# ## Parameters

# %%
# Parameters of training
Learning_rate = 0.0001
epsilon = 1e-8

num_iter = 50000
batch_size = 256

test_ratio = 0.1
gpu_fraction = 0.5

# Ensemble networks (5 networks)
networks = ['network1', 'network2', 'network3', 'network4', 'network5']

# Import Excel File
data = pandas.read_excel('Concrete_Data.xls')
column_names = data.columns

num_rows = len(data)
num_columns = len(column_names) 
num_data = num_columns - 1

# Dense [input size, output size]
dense1 = [num_data, 256]
dense2 = [256, 512]
dense3 = [512, 1024]
dense_mu  = [1024, 1]
dense_sig = [1024, 1]

# %% [markdown]
# ## Get Concrete Dataset
#
# The concrete dataset has `8 features` which are as follows
# - Cement
# - Blast Furnace Slag
# - Fly Ash
# - Superplasticizer
# - Coarse Aggregate
# - Fine Aggregate
# - Age (day)
#
# Also, it has `1 output`
# - Concrete Compressive Strength
#
# The example data is as follows
# <img src="./image/Concrete_dataset.PNG" width="800" alt="Concrete Dataset" />

# %%
data_x = np.zeros([num_rows, num_columns - 1])
data_y = np.zeros([num_rows, 1])

for i in range(num_rows):
    for j in range(num_columns - 1):
        data_x[i, j] = data[column_names[j]][i]
    data_y[i,0] = data[column_names[-1]][i]

num_train_data = int(num_rows * (1 - test_ratio))
num_test_data  = num_rows - num_train_data

train_x = data_x[:num_train_data, :]
train_y = data_y[:num_train_data, :]
test_x  = data_x[num_train_data:, :]
test_y  = data_y[num_train_data:, :]

print("Train data shape: " + str(train_x.shape))
print("Test data shape: " + str(test_x.shape))
# Out:
# Train data shape: (927, 8)
# Test data shape: (103, 8)

# %% [markdown]
# ## Functions

# %%
tf.reset_default_graph()

def weight_variable(name, shape):
    return tf.get_variable(name, shape = shape, initializer = tf.contrib.layers.xavier_initializer(), dtype = tf.float64)

def bias_variable(name, shape):
    return tf.get_variable(name, shape = shape, initializer = tf.contrib.layers.xavier_initializer(), dtype = tf.float64)

# Get networks
def get_network(network_name):
    input_x = tf.placeholder(tf.float64, shape = [None, num_data])
    
    with tf.variable_scope(network_name):
        # Densely connect layer variables
        w_fc1 = weight_variable(network_name + '_w_fc1', dense1)
        b_fc1 = bias_variable(network_name + '_b_fc1', [dense1[1]])
        
        w_fc2 = weight_variable(network_name + '_w_fc2', dense2)
        b_fc2 = bias_variable(network_name + '_b_fc2', [dense2[1]])

        w_fc3 = weight_variable(network_name + '_w_fc3', dense3)
        b_fc3 = bias_variable(network_name + '_b_fc3', [dense3[1]])
        
        w_fc_mu = weight_variable(network_name + '_w_fc_mu', dense_mu)
        b_fc_mu = bias_variable(network_name + '_b_fc_mu', [dense_mu[1]])

        w_fc_sig = weight_variable(network_name + '_w_fc_sig', dense_sig)
        b_fc_sig = bias_variable(network_name + '_b_fc_sig', [dense_sig[1]])

    # Network
    fc1 = tf.nn.relu(tf.matmul(input_x, w_fc1) + b_fc1)
    fc2 = tf.nn.relu(tf.matmul(fc1, w_fc2) + b_fc2)
    fc3 = tf.nn.relu(tf.matmul(fc2, w_fc3) + b_fc3)
    output_mu  = tf.matmul(fc3, w_fc_mu) + b_fc_mu
    output_sig = tf.matmul(fc3, w_fc_sig) + b_fc_sig
    output_sig_pos = tf.log(1 + tf.exp(output_sig)) + 1e-06
    
    y = tf.placeholder(tf.float64, shape = [None, 1])
    
    # Negative Log Likelihood(NLL) 
    loss = tf.reduce_mean(0.5*tf.log(output_sig_pos) + 0.5*tf.div(tf.square(y - output_mu),output_sig_pos)) + 5

    # Get trainable variables
    train_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, network_name) 
    
    # Gradient clipping for preventing nan
    optimizer = tf.train.AdamOptimizer(learning_rate = Learning_rate)
    gvs = optimizer.compute_gradients(loss, var_list = train_vars)
    capped_gvs = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gvs]
    train_opt = optimizer.apply_gradients(capped_gvs)

    return input_x, y, output_mu, output_sig_pos, loss, train_opt, train_vars


# Make batch data 
def making_batch(data_size, sample_size, data_x, data_y):
    
    # Making batches(testing)
    batch_idx = np.random.choice(data_size, sample_size)
    
    batch_x = np.zeros([sample_size, num_data])
    batch_y = np.zeros([sample_size, 1])
        
    for i in range(batch_idx.shape[0]):
        batch_x[i,:] = data_x[batch_idx[i], :]
        batch_y[i,:] = data_y[batch_idx[i], :] 
        
    return batch_x, batch_y

# %% [markdown]
# ## Initialize Ensemble Networks

# %%
x_list = []
y_list = []
output_mu_list = []
output_sig_list = []
loss_list = []
train_list = []
train_var_list = []
output_test_list = []

# Train each ensemble network
for i in range(len(networks)):
    x_input, y, output_mu, output_sig, loss, train_opt, train_vars = get_network(networks[i])

    x_list.append(x_input)
    y_list.append(y)
    output_mu_list.append(output_mu)
    output_sig_list.append(output_sig)
    loss_list.append(loss)
    train_list.append(train_opt)
    train_var_list.append(train_vars)

# %% [markdown]
# ## Create Session

# %%
# Create Session
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = gpu_fraction

sess = tf.InteractiveSession(config=config)
sess.run(tf.global_variables_initializer())

# %% [markdown]
# ## Training

# %%
# Set parameters for printing and testing
num_print = 100
test_size = 10

train_data_num = train_x.shape[0]
test_data_num  = test_x.shape[0]

loss_train = np.zeros([len(networks)])
out_mu     = np.zeros([test_size, len(networks)])
out_sig    = np.zeros([test_size, len(networks)])

for iter in range(num_iter):
    # Making batches(testing)
    batch_x_test, batch_y_test = making_batch(test_data_num, test_size, test_x, test_y)
        
    for i in range(len(networks)):
        # Making batches(training)
        batch_x, batch_y = making_batch(train_data_num, batch_size, train_x, train_y)
       
        # Training
        _, loss, mu, sig = sess.run([train_list[i], loss_list[i], output_mu_list[i], output_sig_list[i]], 
                                               feed_dict = {x_list[i]: batch_x, y_list[i]: batch_y})
  
      
        # Testing
        loss_test, mu_test, sig_test = sess.run([loss_list[i], output_mu_list[i], output_sig_list[i]], 
                                    feed_dict = {x_list[i]: batch_x_test, y_list[i]: batch_y_test})

        if np.any(np.isnan(loss)):
            raise ValueError('There is Nan in loss')
        
        loss_train[i] += loss
        out_mu[:, i] = np.reshape(mu_test, (test_size))
        out_sig[:, i] = np.reshape(sig_test, (test_size))
        
    # Get final test result
    out_mu_final = np.mean(out_mu, axis = 1)
    out_sig_final = np.sqrt(np.mean(out_sig + np.square(out_mu), axis = 1) - np.square(out_mu_final))
    
    if iter % num_print == 0 and iter != 0:
        print(('-------------------------') + ' Iteration: ' + str(iter) + ' -------------------------')
        print('Average Loss(NLL): ' + str(loss_train / num_print))
        print('mu: ' + str(out_mu[0, :]))
        print('std: ' + str(np.sqrt(out_sig[0, :])))
        print('Final mu: ' + str(out_mu_final[0]))
        print('Final std: ' + str(out_sig_final[0]))
        print('Real Value: ' + str(batch_y_test[0]))
        print('\n')
        
        loss_train = np.zeros(len(networks))
# Out:
# ------------------------- Iteration: 100 -------------------------
# Average Loss(NLL): [ 6.97854001  6.99091616  7.03297645  7.16480707  6.97786688]
# mu: [ 31.3308736   29.80584478  24.55121872  25.90735918  28.115926  ]
# std: [ 3.93982435  3.32309722  3.66674279  4.28980896  3.34129046]
# Final mu: 27.9422444561
# Final std: 4.47666548227
# Real Value: [ 23.52423164]
#
#
# ------------------------- Iteration: 200 -------------------------
# Average Loss(NLL): [ 6.8873427   6.93195902  6.96229803  7.17169741  6.91445827]
# mu: [ 40.91410219  40.06703653  43.82972633  46.18089388  45.42716743]
# std: [ 2.45140024  3.23176498  2.89768997  1.68213671  3.12956942]
# Final mu: 43.2837852716
# Final std: 3.6530072867
# Real Value: [ 40.9348796]
#
#
# ------------------------- Iteration: 300 -------------------------
# Average Loss(NLL): [ 6.88858653  6.93659921  6.95661937  7.15630159  6.89825201]
# mu: [ 28.3711658   24.79142181  29.21425681  24.97281956  30.66877373]
# std: [ 2.68353844  3.52099382  3.56844417  4.20581514  1.82011264]
# Final mu: 27.6036875423
# Final std: 4.01851403557
# Real Value: [ 26.92265885]
#
#
# ------------------------- Iteration: 400 -------------------------
# Average Loss(NLL): [ 6.89065196  6.92545042  6.96308443  7.10594379  7.01967411]
# mu: [ 58.3310542   58.75782476  54.38600168  51.78303586  51.96026683]
# std: [ 3.44444837  4.050739    4.00331362  5.11317895  3.72343048]
# Final mu: 55.0436366643
# Final std: 5.08883567693
# Real Value: [ 57.21823429]
#
#
# ------------------------- Iteration: 500 -------------------------
# Average Loss(NLL): [ 6.88577362  6.91941721  6.95736737  7.09450893  6.94031061]
# mu: [ 38.40473012  35.15952962  43.93877797  43.85733122  41.328849  ]
# std: [ 3.89834254  4.27987312  4.51218472  6.4480913   5.96078171]
# Final mu: 40.5378435868
# Final std: 6.12650758677
# Real Value: [ 39.45595358]
#
#
# ------------------------- Iteration: 600 -------------------------
# Average Loss(NLL): [ 6.87731574  6.93589762  6.95448619  7.08321999  7.02281111]
# mu: [ 31.81367345  34.56163588  31.36560235  26.31726723  34.19047433]
# std: [ 4.1778001   3.53837489  3.79568827  5.67835492  3.99951585]
# Final mu: 31.6497306505
# Final std: 5.21725108423
# Real Value: [ 32.76803638]
#
#
# ------------------------- Iteration: 700 -------------------------
# Average Loss(NLL): [ 6.86990126  6.92709847  6.94116663  7.06895674  6.99802371]
# mu: [ 49.83949523  51.01649275  44.49928282  44.79456981  45.81884264]
# std: [ 3.66417975  3.44509338  3.21062658  4.45915392  4.11027962]
# Final mu: 47.1937366511
# Final std: 4.66693424308
# Real Value: [ 45.30477848]
#
#
# ------------------------- Iteration: 800 -------------------------
# Average Loss(NLL): [ 6.87000254  6.92410623  6.94814619  7.07880851  6.98042619]
# mu: [ 30.05129112  27.18154665  38.30611552  44.66519508  34.95598304]
# std: [ 2.44387162  4.15589288  4.14104323  5.85937008  3.40247093]
# Final mu: 35.0320262807
# Final std: 7.43320060911
# Real Value: [ 30.88163004]
#
#
# ------------------------- Iteration: 900 -------------------------
# Average Loss(NLL): [ 6.88403586  6.92905464  6.94587079  7.06678566  7.00202557]
# mu: [ 29.50346394  29.14230485  29.39438405  22.85002891  19.27729563]
# std: [ 3.48421468  3.3238785   4.33492067  7.22594423  6.6386387 ]
# Final mu: 26.0334954727
# Final std: 6.73864816881
# Real Value: [ 29.72606826]
#
#
# ------------------------- Iteration: 1000 -------------------------
# Average Loss(NLL): [ 6.86260819  6.92550716  6.94454363  7.08874025  6.9739223 ]
# mu: [ 12.9413503   15.3150869    7.03729565   5.75947139  12.95427847]
# std: [ 3.6506152   3.7731196   4.47844964  6.79631354  4.39902965]
# Final mu: 10.801496541
# Final std: 6.0388482629
# Real Value: [ 13.29378676]
#
#
# ------------------------- Iteration: 1100 -------------------------
# Average Loss(NLL): [ 6.87253859  6.92621618  6.94932635  7.08580816  6.96980122]
# mu: [ 53.63002001  51.61138301  59.44431315  56.65071314  54.26192755]
# std: [ 3.55990523  4.5044511   3.82053106  4.39071529  3.55918212]
# Final mu: 55.1196713697
# Final std: 4.81279771064
# Real Value: [ 57.21823429]
#
#
# ------------------------- Iteration: 1200 -------------------------
# Average Loss(NLL): [ 6.91657673  6.9219068   6.93993962  7.17227742  6.81906967]
# mu: [ 47.9535108   49.23993385  51.12460129  45.23109991  48.15640176]
# std: [ 3.43484248  3.08827994  3.18018014  4.86398132  3.44862847]
# Final mu: 48.3411095221
# Final std: 4.13310380221
# Real Value: [ 45.30477848]
#
#
# ------------------------- Iteration: 1300 -------------------------
# Average Loss(NLL): [ 6.89149525  6.92566419  6.96818511  7.02669984  6.85276315]
# mu: [ 58.67593972  58.77768697  53.13888003  56.96472846  54.81721155]
# std: [ 3.54147692  4.00529076  4.01119891  4.38514531  4.64925396]
# Final mu: 56.4748893479
# Final std: 4.68579741622
# Real Value: [ 61.23581094]
#
#
# ------------------------- Iteration: 1400 -------------------------
# Average Loss(NLL): [ 6.9238191   6.91484897  6.95790654  7.03422655  7.30633743]
# mu: [ 40.39297497  36.2437257   43.7250537   41.80619334  41.29677488]
# std: [ 4.62776619  4.29717566  4.82564882  3.90966656  3.82476093]
# Final mu: 40.6929445157
# Final std: 4.97526408937
# Real Value: [ 38.46103971]
#
#
# ------------------------- Iteration: 1500 -------------------------
# Average Loss(NLL): [ 7.09712779  6.9270948   6.94070307  6.95462306  6.89172131]
# mu: [ 21.02552522  21.94807934  22.05083405  20.56972529  24.13280501]
# std: [ 5.53754596  4.32125825  4.09958339  7.18340084  5.34262039]
# Final mu: 21.9453937815
# Final std: 5.54659584093
# Real Value: [ 16.50398701]
#
#
# ------------------------- Iteration: 1600 -------------------------
# Average Loss(NLL): [ 7.17787622  6.912895    6.94153393  7.0521358   6.92210898]
# mu: [ 35.81889803  44.74522358  40.34862959  40.74201899  39.69348171]
# std: [ 5.51915757  3.06485421  3.83446221  7.07482393  4.50277144]
# Final mu: 40.2696503801
# Final std: 5.74955491167
# Real Value: [ 23.8903434]
#
#
# ------------------------- Iteration: 1700 -------------------------
# Average Loss(NLL): [ 7.15848948  6.90777461  6.94550879  7.64014609  6.86995145]
# mu: [ 48.12160861  34.73125114  40.92711504  29.17529843  40.29402848]
# std: [  5.69547908   3.71640249   2.88636868  11.08959653   3.82721961]
# Final mu: 38.6498603413
# Final std: 8.8874521598
# Real Value: [ 24.3385028]
#
#
# ------------------------- Iteration: 1800 -------------------------
# Average Loss(NLL): [ 7.15879592  6.91724299  6.94925584  7.19327842  6.91009196]
# mu: [ 17.2074525   17.08448992  18.79111008  11.49953872  18.81484026]
# std: [ 4.7090239   4.15190107  4.13571408  7.29751623  5.77556003]
# Final mu: 16.6794862957
# Final std: 5.99035025856
# Real Value: [ 18.03393426]
#
#
# ------------------------- Iteration: 1900 -------------------------
# Average Loss(NLL): [ 7.146552    6.90958833  6.94249855  7.16019614  6.86861149]
# mu: [ 32.22292097  32.19113409  27.48687688  25.13713263  26.32419397]
# std: [ 5.0669997   3.89418108  4.78654873  6.80957126  5.6586148 ]
# Final mu: 28.6724517055
# Final std: 6.10812088758
# Real Value: [ 31.87516496]
#
#
# ------------------------- Iteration: 2000 -------------------------
# Average Loss(NLL): [ 7.14000525  6.91745614  6.80884798  7.14490313  7.05426561]
# mu: [ 38.04253502  41.05318817  42.93618277  44.28356695  42.42380376]
# std: [ 3.44197676  3.07250629  2.27839183  2.83343197  5.00323829]
# Final mu: 41.7478553345
# Final std: 4.05092881281
# Real Value: [ 40.9348796]
#
#
# ------------------------- Iteration: 2100 -------------------------
# Average Loss(NLL): [ 7.14372128  6.91147582  7.0362951   7.13082139  7.05768359]
# mu: [ 43.25122707  41.21196234  37.94963965  44.162607    40.02297748]
# std: [ 4.80484491  3.66539472  4.56944862  5.50058752  5.46151019]
# Final mu: 41.3196827088
# Final std: 5.33571721456
# Real Value: [ 33.4195912]
#
#
# ------------------------- Iteration: 2200 -------------------------
# Average Loss(NLL): [ 6.85103797  6.91473333  6.8353032   7.28015146  7.03187431]
# mu: [ 24.98685492  25.51773007  22.58638567  20.13255815  28.30139047]
# std: [ 2.00766561  3.16392848  2.85140983  7.2486947   4.49970143]
# Final mu: 24.3049838591
# Final std: 5.16202041441
# Real Value: [ 23.786922]
#
#
# ------------------------- Iteration: 2300 -------------------------
# Average Loss(NLL): [ 6.86184637  6.91130409  6.76149941  7.13315489  7.01407671]
# mu: [ 14.80884937  12.39674748  13.1446629    9.47959371  15.95568593]
# std: [ 4.47964711  4.80304946  5.21340432  9.26449064  6.27059174]
# Final mu: 13.1571078796
# Final std: 6.63520786261
# Real Value: [ 15.42357812]
#
#
# ------------------------- Iteration: 2400 -------------------------
# Average Loss(NLL): [ 6.93765921  6.92429384  6.75837031  7.58419126  6.99793948]
# mu: [ 31.42699076  32.53779445  27.85004688  35.8627903   33.64712682]
# std: [ 3.33432711  4.43376067  3.7430596   9.56102936  4.97317679]
# Final mu: 32.2649498419
# Final std: 6.26187021304
# Real Value: [ 35.31427124]
#
#
# ------------------------- Iteration: 2500 -------------------------
# Average Loss(NLL): [ 6.86338636  6.91889067  6.76283183  7.40635357  6.98490484]
# mu: [ 49.24321602  55.33227607  47.11528045  54.53224642  53.07832178]
# std: [ 4.28115061  4.69465531  3.45464572  8.40010053  4.37087433]
# Final mu: 51.8602681492
# Final std: 6.1969456832
# Real Value: [ 46.23419213]
#
#
# ------------------------- Iteration: 2600 -------------------------
# Average Loss(NLL): [ 6.76808371  6.91994165  6.77220599  7.15121383  6.97809945]
# mu: [ 26.10336424  24.25401835  30.6791079   30.91054888  26.94050585]
# std: [ 3.90882659  3.80960316  2.80969066  5.99023944  4.0071853 ]
# Final mu: 27.7775090441
# Final std: 4.97554825522
# Real Value: [ 23.52423164]
#
#
# ------------------------- Iteration: 2700 -------------------------
# Average Loss(NLL): [ 6.93147715  6.90699107  6.76698281  7.27720859  6.9683195 ]
# mu: [ 33.06648741  29.79733984  28.68796429  27.59483872  30.54608713]
# std: [ 4.00393964  4.63561651  4.44914876  8.14138255  4.27372351]
# Final mu: 29.9385434776
# Final std: 5.64078365831
# Real Value: [ 23.8358748]
#
#
# ------------------------- Iteration: 2800 -------------------------
# Average Loss(NLL): [ 6.92717019  6.91121901  6.7794768   7.43498753  6.95717223]
# mu: [ 29.95973781  36.41765144  36.39378652  38.09566211  36.02708295]
# std: [  4.4363486    3.56023945   3.67120656  10.26521079   3.57573746]
# Final mu: 35.3787841687
# Final std: 6.37607964076
# Real Value: [ 30.88163004]
#
#
# ------------------------- Iteration: 2900 -------------------------
# Average Loss(NLL): [  6.91128015   6.91289924   6.90116173  12.51244165   6.95650098]
# mu: [ 33.27336983  30.17650392  37.5801485   35.48183834  31.09648555]
# std: [ 5.15101906  3.83003139  3.6285385   9.40967252  4.41489472]
# Final mu: 33.5216692293
# Final std: 6.3221590962
# Real Value: [ 33.30651713]
#
#
# ------------------------- Iteration: 3000 -------------------------
# Average Loss(NLL): [ 6.99700351  6.92166802  7.05286292  7.29700656  6.94634741]
# mu: [ 42.97922624  45.99663511  41.30442041  41.35447698  44.60262757]
# std: [ 3.47135127  2.74817041  2.53572328  0.77431492  3.15632916]
# Final mu: 43.2474772616
# Final std: 3.26863182576
# Real Value: [ 40.9348796]
#
#
# ------------------------- Iteration: 3100 -------------------------
# Average Loss(NLL): [ 6.98506771  6.9040546   7.02073781  7.71585863  6.93900169]
# mu: [ 11.39768852  15.90219625   9.8150616    7.65164666  13.39780571]
# std: [  7.91898167   4.62644992   8.21043614  12.51758553   7.58079256]
# Final mu: 11.6328797476
# Final std: 9.01372238626
# Real Value: [ 15.52631004]
#
#
# ------------------------- Iteration: 3200 -------------------------
# Average Loss(NLL): [ 7.10152325  6.91936003  6.95060679  7.61730098  6.93283414]
# mu: [ 36.94118519  36.86712505  32.37622407  35.93228179  28.78333422]
# std: [ 3.35239517  1.70352223  3.47492752  4.7801827   3.51577042]
# Final mu: 34.1800300646
# Final std: 4.72693000324
# Real Value: [ 44.86834018]
#
#
# ------------------------- Iteration: 3300 -------------------------
# Average Loss(NLL): [ 6.9964393   6.72684104  6.98726558  7.36026518  6.93131989]
# mu: [ 32.97406305  33.89471962  27.87366692  29.25218398  36.4343118 ]
# std: [  6.53780052   3.98112068   4.72283998  10.94203957   2.97045551]
# Final mu: 32.085789072
# Final std: 7.18597818058
# Real Value: [ 22.93197176]
#
#
# ------------------------- Iteration: 3400 -------------------------
# Average Loss(NLL): [ 7.02061213  6.76678298  6.8842308   7.2395315   6.92572549]
# mu: [ 38.39046613  38.86070843  40.29932185  38.14348592  43.80591282]
# std: [ 2.55863096  2.31100746  3.11802907  6.43781665  2.50203395]
# Final mu: 39.8999790303
# Final std: 4.27024318656
# Real Value: [ 41.54230795]
#
#
# ------------------------- Iteration: 3500 -------------------------
# Average Loss(NLL): [ 6.99735412  6.72119767  6.82989147  7.20302353  6.92684808]
# mu: [ 34.24102826  34.33512209  38.26262711  42.41467171  33.4514775 ]
# std: [ 3.36758537  2.83762694  3.18583289  5.10862185  3.88070293]
# Final mu: 36.540985333
# Final std: 5.05697730592
# Real Value: [ 33.71882378]
#
#
# ------------------------- Iteration: 3600 -------------------------
# Average Loss(NLL): [ 7.00813095  6.70369939  6.94104799  7.24452258  6.91825255]
# mu: [ 28.52102351  22.65531343  24.70817077  24.77889413  27.56876472]
# std: [ 4.89655411  2.49159868  2.45860004  5.38021692  2.82985392]
# Final mu: 25.6464333116
# Final std: 4.37543628625
# Real Value: [ 23.74417449]
#
#
# ------------------------- Iteration: 3700 -------------------------
# Average Loss(NLL): [ 6.97408093  6.93676953  6.8577526   7.19046166  6.90916981]
# mu: [ 36.0724779   31.54385854  28.451516    38.72558055  35.39859737]
# std: [ 7.23818369  5.45937616  5.19588722  6.06621353  4.96124487]
# Final mu: 34.0384060738
# Final std: 6.8702185355
# Real Value: [ 27.68108245]
#
#
# ------------------------- Iteration: 3800 -------------------------
# Average Loss(NLL): [ 7.02633253  6.99361068  6.82001881  7.40067894  6.91133139]
# mu: [ 36.3914693   36.20652336  38.1363809   34.92089765  30.06190235]
# std: [ 5.11358336  4.64120951  4.66900122  6.67116651  5.07688605]
# Final mu: 35.1434347127
# Final std: 5.95458371477
# Real Value: [ 44.6118551]
#
#
# ------------------------- Iteration: 3900 -------------------------
# Average Loss(NLL): [ 7.03830073  6.98169019  6.85726283  7.06113755  6.90202549]
# mu: [ 18.54842404  20.11104519   5.48586418   9.06403539  11.65271647]
# std: [ 7.013572    5.18453207  7.45193059  8.38392198  6.47530993]
# Final mu: 12.9724170549
# Final std: 8.93239069194
# Real Value: [ 13.46132942]
#
#
# ------------------------- Iteration: 4000 -------------------------
# Average Loss(NLL): [ 6.99189064  6.97134097  7.0423909   7.02557287  6.89555989]
# mu: [ 29.73657096  30.22317501  39.37125394  36.14087067  36.39783874]
# std: [ 4.63946859  4.11143834  3.3404805   5.52137956  3.29987131]
# Final mu: 34.3739418645
# Final std: 5.69012451948
# Real Value: [ 30.88163004]
#
#
# ------------------------- Iteration: 4100 -------------------------
# Average Loss(NLL): [ 6.99955517  6.96340989  7.01684439  7.23289301  6.90780598]
# mu: [ 17.7060927   18.32109689  19.74487798  16.38352073  17.77675965]
# std: [ 4.04344218  3.96174883  4.39771326  4.84099896  4.39295297]
# Final mu: 17.986469589
# Final std: 4.47245071552
# Real Value: [ 19.98790924]
#
#
# ------------------------- Iteration: 4200 -------------------------
# Average Loss(NLL): [ 6.98652813  6.96143636  7.0098063   7.03584447  6.8937485 ]
# mu: [ 40.39583106  39.12053813  32.74344957  37.04259521  35.63172058]
# std: [ 8.08247721  4.38014495  5.86376828  5.60130011  6.22825875]
# Final mu: 36.9868269092
# Final std: 6.70941671721
# Real Value: [ 37.43165204]
#
#
# ------------------------- Iteration: 4300 -------------------------
# Average Loss(NLL): [ 7.13230274  6.95009593  7.00006206  7.10091486  6.8872386 ]
# mu: [ 33.6015657   31.80502698  33.96336214  30.85960837  36.17709462]
# std: [ 4.51410987  3.8602937   4.01507135  5.43408925  2.99754741]
# Final mu: 33.2813315627
# Final std: 4.62410742616
# Real Value: [ 33.30651713]
#
#
# ------------------------- Iteration: 4400 -------------------------
# Average Loss(NLL): [ 6.99301877  6.94533021  6.9981367   6.95054149  6.88501788]
# mu: [ 31.34115445  26.9115853   27.87597164  27.31105306  23.27653961]
# std: [ 6.22802823  4.06028929  4.31369049  6.17157146  3.95033041]
# Final mu: 27.3432608107
# Final std: 5.66688894906
# Real Value: [ 21.91154728]
#
#
# ------------------------- Iteration: 4500 -------------------------
# Average Loss(NLL): [ 6.93535067  6.94651452  6.98240184  6.94367566  6.88210448]
# mu: [ 29.03645834  36.64829359  26.88627505  33.44406648  34.57477429]
# std: [ 6.07517027  3.91776437  3.86517384  5.55918707  4.20795486]
# Final mu: 32.1179735488
# Final std: 6.01651365015
# Real Value: [ 35.31427124]
#
#
# ------------------------- Iteration: 4600 -------------------------
# Average Loss(NLL): [ 7.1270677   6.9468832   6.97167509  7.04036495  6.88373006]
# mu: [ 35.89032632  25.96451976  32.70676094  32.40303673  36.51784906]
# std: [ 7.7414574   3.88357037  3.37802868  6.13252229  3.72895191]
# Final mu: 32.6964985642
# Final std: 6.45205843704
# Real Value: [ 33.05347944]
#
#
# ------------------------- Iteration: 4700 -------------------------
# Average Loss(NLL): [ 7.04020499  6.94984502  6.97727184  7.05139472  6.88427048]
# mu: [ 12.06444318   6.4683547   14.46904163  10.94880416  10.76556297]
# std: [ 5.45839493  4.24271492  5.64321167  5.99844461  5.47124736]
# Final mu: 10.9432413256
# Final std: 5.98833868015
# Real Value: [ 9.73815902]
#
#
# ------------------------- Iteration: 4800 -------------------------
# Average Loss(NLL): [ 7.06274783  6.95220154  6.95454836  7.06031959  6.88820782]
# mu: [ 35.27930813  38.60467053  30.17701231  28.53411025  36.36357838]
# std: [ 6.13499745  4.85919781  2.93016827  6.29616963  2.46628958]
# Final mu: 33.7917359205
# Final std: 6.13613327944
# Real Value: [ 35.22532884]
#
#
# ------------------------- Iteration: 4900 -------------------------
# Average Loss(NLL): [ 7.17276     6.94846811  6.9428503   7.03026625  6.87910885]
# mu: [ 38.95378096  31.79554598  36.96994755  37.88391875  36.04428459]
# std: [ 7.17809752  4.60464744  4.66358989  5.87601125  5.01646648]
# Final mu: 36.3294955667
# Final std: 6.07487785834
# Real Value: [ 33.76226077]
#
#
# ------------------------- Iteration: 5000 -------------------------
# Average Loss(NLL): [ 7.66802469  6.93895671  6.93433155  7.00819433  6.87697567]
# mu: [ 28.85587979  25.9966694   30.9171169   27.20237357  26.1743554 ]
# std: [ 6.2654778   4.5993521   4.40472224  4.7827838   3.82601009]
# Final mu: 27.8292790123
# Final std: 5.18467156975
# Real Value: [ 31.87516496]
#
#
# ------------------------- Iteration: 5100 -------------------------
# Average Loss(NLL): [ 7.06181284  6.93119036  6.94625289  7.00267994  6.87238186]
# mu: [ 40.10298216  37.97718557  33.0335706   37.27445572  34.27312634]
# std: [ 7.33431993  3.83946683  3.14315103  6.28456735  3.92474723]
# Final mu: 36.5322640781
# Final std: 5.76273917285
# Real Value: [ 30.88163004]
#
#
# ------------------------- Iteration: 5200 -------------------------
# Average Loss(NLL): [ 7.05148018  6.94218452  6.92798737  6.99704113  6.86710251]
# mu: [ 20.08155564  16.39733751  21.0946451   25.93695212  22.26329785]
# std: [ 7.0436091   4.84197793  4.74138947  5.28301562  4.25835082]
# Final mu: 21.1547576438
# Final std: 6.15578471271
# Real Value: [ 16.50398701]
#
#
# ------------------------- Iteration: 5300 -------------------------
# Average Loss(NLL): [ 13.19081868   6.93007775   6.93150471   6.97936371   6.86049357]
# mu: [ 34.04191734  31.25613903  38.73420293  30.3072752   30.91779463]
# std: [ 1.5302893   3.15603773  3.56408797  3.47419819  1.84919042]
# Final mu: 33.0514658263
# Final std: 4.22079303863
# Real Value: [ 33.39959639]
#
#
# ------------------------- Iteration: 5400 -------------------------
# Average Loss(NLL): [ 7.19787252  6.94831566  6.93203647  6.97603666  6.87363867]
# mu: [ 22.79788052  31.92195244  24.59232961  29.01404268  26.6651865 ]
# std: [ 8.36894961  3.54637519  3.50629429  5.52689775  4.75524367]
# Final mu: 26.9982783481
# Final std: 6.32325690034
# Real Value: [ 29.72606826]
#
#
# ------------------------- Iteration: 5500 -------------------------
# Average Loss(NLL): [ 7.17200214  6.94462567  6.91823504  6.98652556  6.86534969]
# mu: [ 22.58997295  18.2585562   19.57409748  22.75546439  22.22905932]
# std: [ 5.23483316  3.45329955  3.1417384   4.69519821  3.52260924]
# Final mu: 21.0814300668
# Final std: 4.47858799297
# Real Value: [ 19.98790924]
#
#
# ------------------------- Iteration: 5600 -------------------------
# Average Loss(NLL): [ 7.06028432  6.93092873  6.90286075  6.96386091  6.8516108 ]
# mu: [ 15.68639647   9.50480953  14.62674444   9.87549748   9.61163784]
# std: [ 5.82840213  3.66573408  4.15079226  5.35483639  3.15834233]
# Final mu: 11.8610171519
# Final std: 5.29382352182
# Real Value: [ 13.29378676]
#
#
# ------------------------- Iteration: 5700 -------------------------
# Average Loss(NLL): [ 7.01679607  6.93595004  6.90785205  6.9535783   6.85696669]
# mu: [  9.21567982  11.93073954   8.75143257  15.50177257  14.61554735]
# std: [ 6.13562652  3.8213367   5.36292494  5.44698215  4.62688669]
# Final mu: 12.0030343704
# Final std: 5.82238894567
# Real Value: [ 9.73815902]
#
#
# ------------------------- Iteration: 5800 -------------------------
# Average Loss(NLL): [ 6.91728954  6.93199209  7.2070086   6.91262882  6.85077438]
# mu: [ 34.88894282  31.67467606  37.15473116  24.94826011  35.5823227 ]
# std: [ 5.97524347  4.47402627  5.4601898   4.99999532  2.73416958]
# Final mu: 32.8497865701
# Final std: 6.5112551721
# Real Value: [ 35.22532884]
#
#
# ------------------------- Iteration: 5900 -------------------------
# Average Loss(NLL): [ 7.04354393  6.92741306  6.93690244  7.08077656  6.84618273]
# mu: [ 27.94446044  27.27220461  28.81851206  27.23025962  26.46625466]
# std: [ 4.92948037  4.0837044   3.80329564  5.06785563  3.51950941]
# Final mu: 27.5463382794
# Final std: 4.3961379935
# Real Value: [ 29.87085822]
#
#
# ------------------------- Iteration: 6000 -------------------------
# Average Loss(NLL): [ 7.00667124  6.93068331  6.96574712  9.66545161  6.86269851]
# mu: [ 35.44261675  41.26707562  31.07239463  31.71062228  35.70014871]
# std: [ 5.41083805  3.75491086  4.40510304  5.09623331  4.17283096]
# Final mu: 35.0385715987
# Final std: 5.87139803479
# Real Value: [ 39.0560575]
#
#
# ------------------------- Iteration: 6100 -------------------------
# Average Loss(NLL): [ 7.06638369  6.93505331  6.93775318  6.98048428  6.86350793]
# mu: [ 69.49896588  63.95259634  68.57782808  61.44736458  68.46360688]
# std: [ 6.93238583  4.5191445   4.18934291  5.94868384  3.85027453]
# Final mu: 66.3880723519
# Final std: 6.08876599556
# Real Value: [ 65.90907927]
#
#
# ------------------------- Iteration: 6200 -------------------------
# Average Loss(NLL): [ 7.03898884  6.93511071  6.9505653   6.99319263  6.84573265]
# mu: [ 60.10538203  63.00862841  62.52379968  65.72996129  63.35749619]
# std: [ 3.91764168  4.52673179  4.43154956  5.25971339  3.8145463 ]
# Final mu: 62.9450535207
# Final std: 4.77209069213
# Real Value: [ 65.90907927]
#
#
# ------------------------- Iteration: 6300 -------------------------
# Average Loss(NLL): [ 7.97244587  6.93891169  6.91687522  6.98084679  6.86332205]
# mu: [ 47.72215275  48.18444955  40.92869422  47.0705293   49.42118132]
# std: [ 5.46542037  4.01736873  5.06473567  5.32966612  5.21508186]
# Final mu: 46.6654014263
# Final std: 5.85416996445
# Real Value: [ 41.05346947]
#
#
# ------------------------- Iteration: 6400 -------------------------
# Average Loss(NLL): [ 11.77166775   6.94506692   6.91096156   6.96822118   6.84287846]
# mu: [ 33.05863981  24.61071221  33.66999454  27.70559924  31.87862198]
# std: [ 5.58716509  4.15906322  4.58416665  4.1126635   3.76652582]
# Final mu: 30.1847135572
# Final std: 5.67663601795
# Real Value: [ 26.14768782]
#
#
# ------------------------- Iteration: 6500 -------------------------
# Average Loss(NLL): [ 6.9814987   6.94292209  6.92498917  6.96238114  6.84634719]
# mu: [ 26.47619914  26.37378113  25.06661719  27.20873395  24.84862337]
# std: [ 4.45630044  4.52716618  4.66998702  4.47564777  4.19024612]
# Final mu: 25.9947909559
# Final std: 4.55579769489
# Real Value: [ 36.44363293]
#
#
# ------------------------- Iteration: 6600 -------------------------
# Average Loss(NLL): [ 7.18629699  6.94474259  6.90047933  6.95731991  6.8445571 ]
# mu: [ 15.73344561  16.49139161   9.69076449  13.8493005   12.78894908]
# std: [ 5.2677898   3.65086262  4.29246133  3.99314517  2.99621666]
# Final mu: 13.7107702568
# Final std: 4.75980285319
# Real Value: [ 13.20208645]
#
#
# ------------------------- Iteration: 6700 -------------------------
# Average Loss(NLL): [ 6.96661357  6.95819814  6.85633139  7.23689254  6.83837004]
# mu: [ 27.41635407  24.88674837  28.06410434  29.02872351  28.7525412 ]
# std: [ 5.14000818  4.37506064  4.22703012  4.75887315  3.97971843]
# Final mu: 27.6296942985
# Final std: 4.75162503141
# Real Value: [ 23.69660064]
#
#
# ------------------------- Iteration: 6800 -------------------------
# Average Loss(NLL): [ 6.87508153  6.94501682  6.95075631  6.97736715  6.83209818]
# mu: [ 51.24310822  53.9144524   56.34798642  53.18259471  52.16018828]
# std: [ 4.28650254  4.19443204  4.19545978  4.5348494   3.32474823]
# Final mu: 53.369666006
# Final std: 4.48052054047
# Real Value: [ 57.21823429]
#
#
# ------------------------- Iteration: 6900 -------------------------
# Average Loss(NLL): [ 6.86671795  6.95543915  6.87310643  6.95271154  6.84659754]
# mu: [ 10.90491658  12.47851404   9.97609059  12.40856974  15.24813454]
# std: [ 5.15828777  3.77068735  5.68024255  5.7674532   4.29493037]
# Final mu: 12.2032450985
# Final std: 5.30728314
# Real Value: [ 9.73815902]
#
#
# ------------------------- Iteration: 7000 -------------------------
# Average Loss(NLL): [ 6.91623773  6.95476594  6.90526825  6.94957653  6.8361404 ]
# mu: [ 16.92868592  18.42737386  22.68208049  25.94441984  25.03876274]
# std: [ 4.59950172  4.75893077  5.30727706  5.32049134  4.58737643]
# Final mu: 21.8042645699
# Final std: 6.08062104502
# Real Value: [ 18.28766142]
#
#
# ------------------------- Iteration: 7100 -------------------------
# Average Loss(NLL): [ 6.95507591  6.95007249  6.85582304  6.93269404  6.84522281]
# mu: [ 40.81101299  34.95790688  38.02095096  35.30766273  36.14995756]
# std: [ 4.27079288  4.17728816  3.56985887  5.16288103  3.11184552]
# Final mu: 37.0494982241
# Final std: 4.64936245139
# Real Value: [ 38.6306508]
#
#
# ------------------------- Iteration: 7200 -------------------------
# Average Loss(NLL): [ 6.84232413  6.94993026  6.92202194  6.93106707  6.84418617]
# mu: [ 26.33586427  33.80847556  28.78347152  23.6658798   29.56780825]
# std: [ 4.89427644  4.20167877  6.22375089  4.30072091  3.94962543]
# Final mu: 28.432299878
# Final std: 5.86291107219
# Real Value: [ 36.44363293]
#
#
# ------------------------- Iteration: 7300 -------------------------
# Average Loss(NLL): [ 6.9222827   6.96363075  7.16342531  6.93418817  6.83829366]
# mu: [ 33.58663944  30.90325977  33.01351161  35.51697935  33.97548049]
# std: [ 5.13216519  4.23673039  7.02092371  2.95348942  3.05589662]
# Final mu: 33.3991741327
# Final std: 4.95731122354
# Real Value: [ 32.96384756]
#
#
# ------------------------- Iteration: 7400 -------------------------
# Average Loss(NLL): [ 6.9548481   6.96012992  6.8129251   6.9404318   6.84042793]
# mu: [ 42.86658766  33.94498938  40.78628487  34.19292131  34.16338197]
# std: [ 3.48383117  4.32502921  2.81029983  4.35764103  3.68600437]
# Final mu: 37.1908330381
# Final std: 5.38788095939
# Real Value: [ 37.17103011]
#
#
# ------------------------- Iteration: 7500 -------------------------
# Average Loss(NLL): [ 7.00102652  6.96160473  6.8570646   6.92240233  6.83535937]
# mu: [ 24.08614089  33.97504265  27.13902684  25.88377725  27.52208732]
# std: [ 5.36434172  3.62628943  4.13349311  4.31481072  4.30665426]
# Final mu: 27.7212149897
# Final std: 5.51825445688
# Real Value: [ 29.72606826]
#
#
# ------------------------- Iteration: 7600 -------------------------
# Average Loss(NLL): [ 6.89048024  6.96368211  6.85181479  6.91009879  6.82255367]
# mu: [ 47.3073042   49.15420582  50.60396365  48.86287707  54.39682042]
# std: [ 4.58660079  4.89689812  2.17696921  4.94184476  3.35670527]
# Final mu: 50.0650342309
# Final std: 4.78287976974
# Real Value: [ 53.52471136]
#
#
# ------------------------- Iteration: 7700 -------------------------
# Average Loss(NLL): [ 6.89350321  6.95618103  6.92018112  6.91692116  6.82379874]
# mu: [ 22.16577129  19.76761418  19.14749399  19.28556378  20.5851347 ]
# std: [ 3.45065907  3.67629999  4.37980334  5.26175691  2.99728885]
# Final mu: 20.1903155874
# Final std: 4.18133399078
# Real Value: [ 15.340841]
#
#
# ------------------------- Iteration: 7800 -------------------------
# Average Loss(NLL): [ 7.00770527  6.96123844  6.82216999  6.9152887   6.86163566]
# mu: [ 31.4631855   34.0436945   30.92520817  27.50581439  29.74077286]
# std: [ 3.82723699  4.15564304  4.65332129  4.86588105  3.65036583]
# Final mu: 30.7357350844
# Final std: 4.76450411531
# Real Value: [ 23.8358748]
#
#
# ------------------------- Iteration: 7900 -------------------------
# Average Loss(NLL): [ 6.81874831  6.95883771  6.81796524  6.89995723  6.84180749]
# mu: [ 20.00002908  16.33473421  16.26712828  21.00640056  19.29884115]
# std: [ 5.9246059   4.63572454  4.91586952  4.82183509  3.89740718]
# Final mu: 18.5814266559
# Final std: 5.25371802452
# Real Value: [ 17.95947085]
#
#
# ------------------------- Iteration: 8000 -------------------------
# Average Loss(NLL): [ 6.90178317  6.965906    6.86243552  6.9009456   6.82707388]
# mu: [ 44.25663773  36.73815123  37.37151588  38.95406795  37.03970591]
# std: [ 5.09224431  4.5962266   5.66087166  4.87616262  4.73119652]
# Final mu: 38.8720157394
# Final std: 5.73456231593
# Real Value: [ 39.45595358]
#
#
# ------------------------- Iteration: 8100 -------------------------
# Average Loss(NLL): [ 6.91477963  6.96763486  6.90227438  6.90103622  6.8215015 ]
# mu: [ 26.75017879  27.482475    23.87502031  24.33904987  27.10371117]
# std: [ 4.34872935  3.72465472  5.71009242  2.76929059  2.75587336]
# Final mu: 25.9100870272
# Final std: 4.28639742681
# Real Value: [ 26.92265885]
#
#
# ------------------------- Iteration: 8200 -------------------------
# Average Loss(NLL): [ 6.86802291  6.96001892  6.74098072  6.90962837  6.81566049]
# mu: [ 30.02300524  27.93954537  20.89479334  29.14847754  30.86038721]
# std: [ 4.19129166  4.08610064  5.21178151  4.05035062  4.02554765]
# Final mu: 27.7732417389
# Final std: 5.61889794299
# Real Value: [ 36.44363293]
#
#
# ------------------------- Iteration: 8300 -------------------------
# Average Loss(NLL): [ 6.84357216  6.96458084  6.84747718  6.91316108  6.82036067]
# mu: [ 21.05896399  13.59788155  19.59103586  17.67175235  15.42529878]
# std: [ 5.92045283  4.74937515  7.07094798  6.15716779  4.48646197]
# Final mu: 17.4689865072
# Final std: 6.35987337062
# Real Value: [ 15.42357812]
#
#
# ------------------------- Iteration: 8400 -------------------------
# Average Loss(NLL): [ 6.89400388  6.96494276  6.8527699   6.90835782  6.82327261]
# mu: [ 35.06657073  35.34927394  31.31685669  31.46073981  35.2231368 ]
# std: [ 5.31885373  4.3957237   4.76859236  4.33933862  4.29064973]
# Final mu: 33.6833155934
# Final std: 5.00382717391
# Real Value: [ 27.68108245]
#
#
# ------------------------- Iteration: 8500 -------------------------
# Average Loss(NLL): [ 6.83902866  6.9655508   6.92142462  6.89199804  6.81569982]
# mu: [ 26.32596507  21.55040603  26.21717115  28.70022728  26.97073286]
# std: [ 3.03557821  3.59854707  4.52697546  2.69743461  3.27627296]
# Final mu: 25.952900478
# Final std: 4.21527370125
# Real Value: [ 23.786922]
#
#
# ------------------------- Iteration: 8600 -------------------------
# Average Loss(NLL): [ 6.88052553  6.96346425  6.88622567  6.8997769   6.82411408]
# mu: [ 26.24810085  28.25071356  25.20552683  29.42225552  35.60260671]
# std: [ 5.22942293  4.4425161   2.41028134  4.66839853  0.2937875 ]
# Final mu: 28.9458406939
# Final std: 5.31155307018
# Real Value: [ 22.93197176]
#
#
# ------------------------- Iteration: 8700 -------------------------
# Average Loss(NLL): [ 6.82686136  6.96940025  6.91639389  6.88260054  6.81958598]
# mu: [ 34.23172428  35.90497699  32.03945438  27.41233781  30.79334756]
# std: [ 5.85461905  3.9919081   4.11756478  2.39707874  3.45008583]
# Final mu: 32.0763682038
# Final std: 5.05014459485
# Real Value: [ 33.05347944]
#
#
# ------------------------- Iteration: 8800 -------------------------
# Average Loss(NLL): [ 6.85462612  6.97753895  6.81903194  6.88981309  6.82609665]
# mu: [ 38.83737608  37.8428852   40.14569753  42.05094262  43.55361999]
# std: [ 1.48927684  3.38304105  3.38133841  3.78505647  1.54749964]
# Final mu: 40.4861042841
# Final std: 3.56361977481
# Real Value: [ 41.54230795]
#
#
# ------------------------- Iteration: 8900 -------------------------
# Average Loss(NLL): [ 6.93261451  6.98401238  7.35007948  6.90229453  6.82797258]
# mu: [ 43.53938627  41.13174123  39.38468679  41.17026842  40.52498741]
# std: [ 2.80539987  2.71145923  3.47218086  3.18098734  3.00222405]
# Final mu: 41.1502140241
# Final std: 3.33548291623
# Real Value: [ 46.24729218]
#
#
# ------------------------- Iteration: 9000 -------------------------
# Average Loss(NLL): [ 6.92270301  6.97748705  6.82049922  6.88757794  6.83048197]
# mu: [ 36.84166102  43.52061634  35.29760407  34.57720703  37.20861828]
# std: [ 3.74271162  4.17491153  4.62684712  4.01351045  3.29917359]
# Final mu: 37.4891413504
# Final std: 5.09896293306
# Real Value: [ 42.6440906]
#
#
# ------------------------- Iteration: 9100 -------------------------
# Average Loss(NLL): [ 6.79066664  6.98949252  6.91021541  6.8786645   6.82355609]
# mu: [ 28.24022218  30.26790557  31.67581219  35.20930627  34.28400038]
# std: [ 3.18797788  3.9678873   4.1967018   3.78017284  2.74379616]
# Final mu: 31.9354493161
# Final std: 4.42886918328
# Real Value: [ 30.12320644]
#
#
# ------------------------- Iteration: 9200 -------------------------
# Average Loss(NLL): [ 6.84626316  6.99287088  6.94975205  6.89092229  7.01075018]
# mu: [ 45.48048693  44.33367414  44.77356283  43.18631746  44.48101663]
# std: [ 2.52865234  2.56856409  4.77448116  3.60765303  3.09720787]
# Final mu: 44.4510115969
# Final std: 3.49780244817
# Real Value: [ 49.77327244]
#
#
# ------------------------- Iteration: 9300 -------------------------
# Average Loss(NLL): [ 6.9932626   6.99377057  7.1592331   6.88285075  6.84344001]
# mu: [ 44.71545296  44.62131544  42.1164373   40.32945967  45.51348528]
# std: [ 3.90043456  4.21090858  3.25152406  4.13269086  3.36184017]
# Final mu: 43.4592301284
# Final std: 4.2578330305
# Real Value: [ 35.86585204]
#
#
# ------------------------- Iteration: 9400 -------------------------
# Average Loss(NLL): [ 6.84271689  6.99360094  6.99467843  6.88662289  6.84118969]
# mu: [ 52.17755939  46.86464383  48.1940819   48.7870766   47.91153128]
# std: [ 4.88999969  5.10517054  6.73919798  4.60484657  3.57234713]
# Final mu: 48.7869785974
# Final std: 5.39754151671
# Real Value: [ 53.52471136]
#
#
# ------------------------- Iteration: 9500 -------------------------
# Average Loss(NLL): [ 7.26830117  6.99011689  6.89144594  6.88636999  6.82620364]
# mu: [ 29.23647804  27.61472648  31.53104929  28.91988164  40.08659846]
# std: [ 4.47236404  4.44374018  4.83394068  4.1702587   0.39144419]
# Final mu: 31.4777467823
# Final std: 6.02103295928
# Real Value: [ 22.93197176]
#
#
# ------------------------- Iteration: 9600 -------------------------
# Average Loss(NLL): [ 6.84445211  6.98840796  6.76908891  6.88071247  6.84714734]
# mu: [ 41.40645093  46.31360516  40.24542952  37.85311197  41.44619851]
# std: [ 2.82387114  2.7362393   3.58542369  3.08396556  1.48988044]
# Final mu: 41.4529592196
# Final std: 3.95201771259
# Real Value: [ 41.54230795]
#
#
# ------------------------- Iteration: 9700 -------------------------
# Average Loss(NLL): [ 6.87424623  6.99810331  6.90158408  6.88442774  6.83259227]
# mu: [ 32.91583965  29.08604999  30.57202079  38.78935914  30.25125713]
# std: [ 4.06380543  4.51761157  5.85877893  3.49153483  3.64398156]
# Final mu: 32.3229053413
# Final std: 5.59855674292
# Real Value: [ 35.31427124]
#
#
# ------------------------- Iteration: 9800 -------------------------
# Average Loss(NLL): [ 6.80984479  6.99702946  6.79128358  6.88208597  6.85262345]
# mu: [ 47.43996774  37.61821663  39.734356    37.8651133   41.15685885]
# std: [ 4.75799954  4.01747916  7.24349253  3.92065801  3.46501981]
# Final mu: 40.7629025056
# Final std: 6.0449540129
# Real Value: [ 29.41304616]
#
#
# ------------------------- Iteration: 9900 -------------------------
# Average Loss(NLL): [ 6.74349291  6.99810522  6.76839207  6.88621863  6.85411162]
# mu: [ 18.54420654  26.37981599  20.6184809   21.55394048  24.03290317]
# std: [ 4.48007547  4.64355589  6.61340001  4.27388609  4.60177665]
# Final mu: 22.2258694162
# Final std: 5.69075862816
# Real Value: [ 18.28766142]
#
#
# ------------------------- Iteration: 10000 -------------------------
# Average Loss(NLL): [ 6.92245526  6.99504393  6.77243055  6.87534057  6.93407957]
# mu: [ 39.12303214  38.98247973  43.15064893  43.36883377  43.61799113]
# std: [ 2.24547955  3.51978857  4.73947582  3.72777618  0.08404341]
# Final mu: 41.6485971373
# Final std: 3.90839216201
# Real Value: [ 41.54230795]
#
#
# ------------------------- Iteration: 10100 -------------------------
# Average Loss(NLL): [ 6.88643416  6.9923207   6.74925833  6.88288717  7.93318524]
# mu: [ 36.14635695  36.73532401  40.82801437  40.84199734  41.97746475]
# std: [ 5.33051773  5.24575009  6.37389967  4.57329361  7.05350778]
# Final mu: 39.3058314841
# Final std: 6.25508041919
# Real Value: [ 39.45595358]
#
#
# ------------------------- Iteration: 10200 -------------------------
# Average Loss(NLL): [ 6.8426924   6.98984646  6.91242761  6.88378636  6.97913166]
# mu: [ 33.50483682  35.2910905   32.11511447  30.50605755  31.62991286]
# std: [ 4.42041654  4.1880413   3.78647738  4.20272888  5.3077688 ]
# Final mu: 32.6094024414
# Final std: 4.7090032214
# Real Value: [ 29.07313449]
#
#
# ------------------------- Iteration: 10300 -------------------------
# Average Loss(NLL): [ 6.8659234   7.00622566  6.88190621  6.88646845  7.03598863]
# mu: [ 58.69119312  56.24260549  58.85914622  59.12854637  55.62316546]
# std: [ 4.31084214  4.96766786  3.37858755  4.39120836  3.38835167]
# Final mu: 57.7089313315
# Final std: 4.38732824876
# Real Value: [ 61.23581094]
#
#
# ------------------------- Iteration: 10400 -------------------------
# Average Loss(NLL): [ 6.86547436  7.00081645  6.78387846  6.88786797  6.84802218]
# mu: [ 29.1332016   26.67639971  29.20603378  28.82283013  28.45255599]
# std: [ 3.11257227  4.19394705  3.79723758  2.85186643  5.26400596]
# Final mu: 28.4582042434
# Final std: 4.04627962107
# Real Value: [ 28.9379972]
#
#
# ------------------------- Iteration: 10500 -------------------------
# Average Loss(NLL): [ 6.85906034  7.00504981  6.75292376  6.87897379  6.96167982]
# mu: [  7.50849662  18.57777534  13.12461753   7.65600423   5.33473362]
# std: [ 4.07089858  4.41635081  5.89161945  4.03566027  5.49900583]
# Final mu: 10.4403254658
# Final std: 6.82864284988
# Real Value: [ 12.4595208]
#
#
# ------------------------- Iteration: 10600 -------------------------
# Average Loss(NLL): [ 6.8435705   7.00432652  6.8169754   6.88233385  6.94401795]
# mu: [ 30.95923368  21.71700477  25.64002312  29.0169453   26.78879768]
# std: [ 3.66093621  4.00750779  0.70801982  3.30883442  3.24805674]
# Final mu: 26.8244009088
# Final std: 4.49122987953
# Real Value: [ 26.92265885]
#
#
# ------------------------- Iteration: 10700 -------------------------
# Average Loss(NLL): [ 6.83070571  7.00590998  6.68093982  6.88543502  6.94008021]
# mu: [ 30.46967673  25.88047551  30.2998722   28.28822871  28.83116627]
# std: [ 4.43057558  4.81642324  3.86017844  4.08287407  4.06014639]
# Final mu: 28.7538838838
# Final std: 4.57595602636
# Real Value: [ 23.8358748]
#
#
# ------------------------- Iteration: 10800 -------------------------
# Average Loss(NLL): [ 6.72799878  7.00394104  6.74699726  6.89324794  6.90562184]
# mu: [ 56.8371472   62.68688481  58.75146677  53.09014533  55.92922051]
# std: [ 4.45563142  4.87814174  4.02590219  4.14406011  4.26651252]
# Final mu: 57.4589729228
# Final std: 5.40459502984
# Real Value: [ 61.23581094]
#
#
# ------------------------- Iteration: 10900 -------------------------
# Average Loss(NLL): [ 6.7043216   7.00798766  6.74493857  6.88871464  6.82418424]
# mu: [ 31.37695593  30.27882926  29.56228009  31.32916021  26.94914474]
# std: [ 3.1619201   3.91054861  2.33935823  3.56571433  3.36035685]
# Final mu: 29.8992740449
# Final std: 3.68668010934
# Real Value: [ 25.10382116]
#
#
# ------------------------- Iteration: 11000 -------------------------
# Average Loss(NLL): [ 6.70313684  7.00951594  6.7330366   6.88874711  6.86048297]
# mu: [ 33.32667006  31.67777611  35.4516983   31.8329059   26.99806454]
# std: [ 4.639185    4.73857451  3.5435904   2.66009743  6.32644782]
# Final mu: 31.8574229848
# Final std: 5.33585906077
# Real Value: [ 32.96384756]
#
#
# ------------------------- Iteration: 11100 -------------------------
# Average Loss(NLL): [ 6.74714573  7.01417647  6.7989598   6.87355265  7.439768  ]
# mu: [ 41.60070964  44.65305085  41.5585476   38.91828918  38.25252172]
# std: [ 4.4568847   3.65688094  3.79461137  3.93022884  4.59129555]
# Final mu: 40.9966237986
# Final std: 4.6917390442
# Real Value: [ 39.42147978]
#
#
# ------------------------- Iteration: 11200 -------------------------
# Average Loss(NLL): [ 7.00399812  7.0103524   6.7156392   6.884797    6.97827916]
# mu: [ 32.51043872  35.15239508  34.63945765  38.07082957  36.63568279]
# std: [ 6.13524504  5.15399118  4.62599492  4.61839612  5.17641987]
# Final mu: 35.4017607602
# Final std: 5.50234705264
# Real Value: [ 39.0560575]
#
#
# ------------------------- Iteration: 11300 -------------------------
# Average Loss(NLL): [ 6.8785594   6.99996557  6.75773597  6.88611826  6.96551397]
# mu: [ 37.63588242  34.14716062  32.87748009  33.24479299  33.48787302]
# std: [ 3.84887848  5.19734596  4.18866521  4.53697557  5.92483223]
# Final mu: 34.2786378278
# Final std: 5.09911238995
# Real Value: [ 39.0560575]
#
#
# ------------------------- Iteration: 11400 -------------------------
# Average Loss(NLL): [ 6.88306224  7.01096495  6.73572062  6.87768308  6.86890918]
# mu: [ 22.67711975  27.35726712  24.00613421  20.45719866  25.64324574]
# std: [ 3.96630367  4.98726689  4.126897    4.24920526  7.3591357 ]
# Final mu: 24.0281930966
# Final std: 5.62347426894
# Real Value: [ 18.28766142]
#
#
# ------------------------- Iteration: 11500 -------------------------
# Average Loss(NLL): [ 6.86216054  7.03347202  6.75472267  6.88895754  6.90792835]
# mu: [ 28.27036547  25.29278716  26.49199575  32.62226028  30.1069167 ]
# std: [ 3.48963501  5.39592761  3.9166187   3.33274265  6.53617273]
# Final mu: 28.5568650737
# Final std: 5.37386801116
# Real Value: [ 25.5595648]
#
#
# ------------------------- Iteration: 11600 -------------------------
# Average Loss(NLL): [ 6.86065753  7.01965161  6.98237098  6.89575078  6.99318721]
# mu: [ 33.96734125  27.81557438  34.1480615   34.90517932  28.70264658]
# std: [ 4.45136424  4.51921909  3.85572526  3.95160252  6.15766018]
# Final mu: 31.9077606051
# Final std: 5.54798390133
# Real Value: [ 30.88163004]
#
#
# ------------------------- Iteration: 11700 -------------------------
# Average Loss(NLL): [ 6.82304053  7.01826675  6.72555006  6.89538368  6.90305497]
# mu: [ 26.39595043  29.32184213  25.39439234  23.9769772   24.11027242]
# std: [ 3.32001271  3.97037087  2.31854789  3.21866208  4.50656621]
# Final mu: 25.8398869056
# Final std: 4.04782907834
# Real Value: [ 23.74417449]
#
#
# ------------------------- Iteration: 11800 -------------------------
# Average Loss(NLL): [ 6.75712734  7.02599028  6.68223136  6.89793138  7.10851814]
# mu: [ 12.80273193  11.15954958  13.25481373  17.06208953  12.51399897]
# std: [ 4.2907542   4.39101199  4.58874852  4.27717418  4.77517279]
# Final mu: 13.3586367506
# Final std: 4.8873189842
# Real Value: [ 13.20208645]
#
#
# ------------------------- Iteration: 11900 -------------------------
# Average Loss(NLL): [ 6.92031248  7.02185171  6.62562588  6.89771961  7.11054065]
# mu: [ 33.73422707  30.15456643  32.37675812  31.50857351  23.18418401]
# std: [ 4.3121296   4.42583191  2.54392615  2.84172303  8.21514648]
# Final mu: 30.19166183
# Final std: 6.13812387783
# Real Value: [ 32.96384756]
#
#
# ------------------------- Iteration: 12000 -------------------------
# Average Loss(NLL): [ 6.8600406   7.02781688  6.62237086  6.88429355  7.03908763]
# mu: [ 30.85669386  38.71390318  36.41819826  31.76696171  38.47323966]
# std: [ 2.58826319  4.31272969  2.99060872  2.84674576  3.44066351]
# Final mu: 35.2457993351
# Final std: 4.67696063022
# Real Value: [ 33.39959639]
#
#
# ------------------------- Iteration: 12100 -------------------------
# Average Loss(NLL): [ 6.84611014  7.02188981  6.58636459  6.91372202  7.00361023]
# mu: [ 35.60753457  35.5075451   40.26697918  44.03393933  38.02443224]
# std: [ 4.06112925  4.53484166  3.60177841  3.95056623  4.01666636]
# Final mu: 38.6880860853
# Final std: 5.15534819143
# Real Value: [ 36.80491836]
#
#
# ------------------------- Iteration: 12200 -------------------------
# Average Loss(NLL): [ 6.84606358  7.02136735  6.91450029  6.90334752  6.94234501]
# mu: [ 42.86345284  37.74554284  40.9763115   39.7356752   42.64253274]
# std: [ 2.60065247  4.00300821  4.04909869  3.87774468  5.0645527 ]
# Final mu: 40.7927030255
# Final std: 4.4275353412
# Real Value: [ 39.42147978]
#
#
# ------------------------- Iteration: 12300 -------------------------
# Average Loss(NLL): [ 6.8380965   7.03095519  6.59696378  6.89841471  6.87050481]
# mu: [ 27.30914103  33.75227474  31.10161077  27.71036672  31.91493846]
# std: [ 3.66654199  3.85968257  2.46660691  3.40095056  5.79682303]
# Final mu: 30.3576663449
# Final std: 4.69889495743
# Real Value: [ 29.87085822]
#
#
# ------------------------- Iteration: 12400 -------------------------
# Average Loss(NLL): [ 6.85016855  7.03296627  6.66686213  6.89184212  8.09154006]
# mu: [ 28.54553554  22.73695663  23.59136184  27.74199511  24.25447413]
# std: [ 1.97749273  4.65244073  0.45991401  2.7961521   4.86203847]
# Final mu: 25.3740646509
# Final std: 4.10551485321
# Real Value: [ 23.786922]
#
#
# ------------------------- Iteration: 12500 -------------------------
# Average Loss(NLL): [ 6.84327643  7.04342443  6.70308798  6.89164269  6.86541307]
# mu: [ 45.23369501  38.87779538  36.04394013  38.60468614  49.17632824]
# std: [ 4.85711098  4.16905891  3.38319829  4.30475378  5.57377367]
# Final mu: 41.5872889801
# Final std: 6.63132344947
# Real Value: [ 29.41304616]
#
#
# ------------------------- Iteration: 12600 -------------------------
# Average Loss(NLL): [ 6.82442424  7.04105548  6.71336872  6.88305813  7.04129402]
# mu: [ 31.86828293  38.35837531  32.59114332  26.25085618  34.33083727]
# std: [ 4.77391838  4.71232723  3.49400573  2.78403011  5.98922405]
# Final mu: 32.6798990024
# Final std: 5.96315200397
# Real Value: [ 33.05347944]
#
#
# ------------------------- Iteration: 12700 -------------------------
# Average Loss(NLL): [ 6.81114262  7.03740959  6.6110131   6.87719816  6.9933136 ]
# mu: [ 31.02269844  24.82946331  26.36123479  32.86744909  29.71628702]
# std: [ 3.05332684  4.61706097  2.12212878  3.73847473  6.60504085]
# Final mu: 28.9594265301
# Final std: 5.2279252282
# Real Value: [ 26.85991653]
#
#
# ------------------------- Iteration: 12800 -------------------------
# Average Loss(NLL): [ 6.80665305  7.03234907  6.63841456  6.88988925  6.93502797]
# mu: [ 52.39501594  54.37459755  59.12791163  53.61927938  54.57864634]
# std: [ 3.06662412  4.84266642  3.0192999   3.97679613  4.9201413 ]
# Final mu: 54.81909017
# Final std: 4.65040820598
# Real Value: [ 57.21823429]
#
#
# ------------------------- Iteration: 12900 -------------------------
# Average Loss(NLL): [ 6.80968761  7.03566713  6.57676816  6.88068761  6.94701144]
# mu: [ 52.55181279  62.55568032  56.5343549   52.91869686  55.53829573]
# std: [ 2.89151867  4.4287694   2.32100002  3.51855304  3.97912605]
# Final mu: 56.0197681176
# Final std: 5.0285922478
# Real Value: [ 57.21823429]
#
#
# ------------------------- Iteration: 13000 -------------------------
# Average Loss(NLL): [ 6.7121261   7.04039641  6.63771007  6.89390315  6.88346256]
# mu: [ 20.2152917   16.41149435  18.56243976  23.22529546  25.25580502]
# std: [ 3.50731723  5.13804578  3.10503229  4.01082283  6.3464278 ]
# Final mu: 20.7340652592
# Final std: 5.56826581182
# Real Value: [ 16.50398701]
#
#
# ------------------------- Iteration: 13100 -------------------------
# Average Loss(NLL): [ 6.67596555  7.03687896  6.57845552  6.8821466   6.83794568]
# mu: [ 32.47350971  38.81991429  37.13840853  35.60173     38.14183231]
# std: [ 4.09931541  4.5661089   3.58625304  4.04645682  5.1792373 ]
# Final mu: 36.435078967
# Final std: 4.88255835401
# Real Value: [ 44.6118551]
#
#
# ------------------------- Iteration: 13200 -------------------------
# Average Loss(NLL): [ 6.65041046  7.0462905   6.59793641  6.89413257  6.81182806]
# ...
# mu: [ 27.83129454  34.03328902  27.86442485  30.9980076   26.94817616]
# std: [ 3.46999701  6.90516456  4.08563291  4.12944645  2.43717227]
# Final mu: 29.535038433
# Final std: 5.18009259347
# Real Value: [ 26.14768782]
#
#
# ------------------------- Iteration: 20700 -------------------------
# Average Loss(NLL): [ 6.69173674  7.51195556  6.82239273  6.88800547  6.66463798]
# mu: [ 35.39676808  25.98300446  40.85189795  40.10948752  33.2597962 ]
# std: [ 3.66559102  7.37796348  5.79551691  4.99449231  4.68584062]
# Final mu: 35.1201908424
# Final std: 7.65679124094
# Real Value: [ 39.0560575]
#
#
# ------------------------- Iteration: 20800 -------------------------
# Average Loss(NLL): [ 6.75055686  7.50049707  6.85817926  6.89458507  6.6437036 ]
# mu: [ 42.20687314  53.88122024  46.07063571  39.4512489   44.0578745 ]
# std: [ 3.97997494  7.74784453  6.45219772  3.7668633   3.2695629 ]
# Final mu: 45.1335704984
# Final std: 7.23588801699
# Real Value: [ 40.8686899]
#
#
# ------------------------- Iteration: 20900 -------------------------
# Average Loss(NLL): [ 6.71055867  7.49781936  6.86082358  6.88422781  6.66617078]
# mu: [ 26.20484106  19.43192396  29.2886461   28.18081556  27.377044  ]
# std: [ 2.59001689  6.69248503  5.5043365   3.90602367  5.14232446]
# Final mu: 26.0966541365
# Final std: 6.06791657801
# Real Value: [ 26.85991653]
#
#
# ------------------------- Iteration: 21000 -------------------------
# Average Loss(NLL): [ 6.70943651  7.49411953  6.88390886  6.89042071  6.67958366]
# mu: [ 26.9544527   34.3543967   22.68476805  28.76308465  24.5117748 ]
# std: [ 1.21946402  6.50899     8.24491103  3.56390028  4.32781444]
# Final mu: 27.4536953795
# Final std: 6.69693887057
# Real Value: [ 23.786922]
#
#
# ------------------------- Iteration: 21100 -------------------------
# Average Loss(NLL): [ 6.70339935  7.48335911  6.83146826  6.90561297  6.70964218]
# mu: [ 42.15500261  29.62955985  40.36489218  38.25250838  42.07770901]
# std: [ 3.45592288  6.25892432  4.5457699   4.04674707  3.69470693]
# Final mu: 38.4959344079
# Final std: 6.48369228883
# Real Value: [ 35.86585204]
#
#
# ------------------------- Iteration: 21200 -------------------------
# Average Loss(NLL): [ 6.70614029  7.48617506  6.84421733  6.88735889  6.66768246]
# mu: [ 37.38236105  48.30457862  38.40065905  38.05790161  38.46136783]
# std: [ 3.27976234  6.76545931  4.24995209  3.77683838  3.19816533]
# Final mu: 40.121373633
# Final std: 6.05845808112
# Real Value: [ 42.6440906]
#
#
# ------------------------- Iteration: 21300 -------------------------
# Average Loss(NLL): [ 6.69833186  7.47966345  6.85021894  6.8939627   6.66103382]
# mu: [ 36.63691796  26.96263554  34.17918623  34.77752971  31.48334399]
# std: [ 3.65163447  6.90937806  6.46996112  4.30792398  3.33286961]
# Final mu: 32.8079226866
# Final std: 6.14724940367
# Real Value: [ 31.1787942]
#
#
# ------------------------- Iteration: 21400 -------------------------
# Average Loss(NLL): [ 6.72630524  7.47618523  6.72972109  6.8819772   6.66236333]
# mu: [ 34.18785698  44.03186254  36.19942647  27.23222342  35.17281438]
# std: [ 4.09392876  7.46161641  6.50831633  3.86547685  2.8806647 ]
# Final mu: 35.3648367578
# Final std: 7.50212934647
# Real Value: [ 33.76226077]
#
#
# ------------------------- Iteration: 21500 -------------------------
# Average Loss(NLL): [ 6.64733128  7.47694617  6.79752338  6.88188871  6.62748237]
# mu: [ 35.98152227  24.0852701   35.39083254  40.2470285   34.34325293]
# std: [ 3.48656612  6.8555084   6.97786012  3.49494426  2.92530853]
# Final mu: 34.0095812681
# Final std: 7.3745803866
# Real Value: [ 24.5798194]
#
#
# ------------------------- Iteration: 21600 -------------------------
# Average Loss(NLL): [ 6.78481967  7.47538978  6.75910483  6.87249441  6.81757007]
# mu: [ 31.68812854  41.50147541  36.27678065  34.93967429  34.40677277]
# std: [ 1.53270971  5.62763274  3.94389386  3.0486533   3.42232901]
# Final mu: 35.7625663303
# Final std: 4.95774617076
# Real Value: [ 33.39959639]
#
#
# ------------------------- Iteration: 21700 -------------------------
# Average Loss(NLL): [ 6.75677656  7.46726761  6.75110366  6.87364203  6.86606594]
# mu: [ 47.38198631  40.65244692  49.56275203  45.11350746  42.28986696]
# std: [ 2.72917314  5.53222587  4.04979097  3.47019721  2.64747137]
# Final mu: 45.0001119358
# Final std: 5.02508859341
# Real Value: [ 45.30477848]
#
#
# ------------------------- Iteration: 21800 -------------------------
# Average Loss(NLL): [ 6.74392827  7.4570004   6.78558872  6.87687317  6.87177678]
# mu: [ 35.04509993  37.07422703  35.33314243  34.01802685  29.19502161]
# std: [ 2.72585837  6.03693009  4.11649237  4.01645837  3.6466995 ]
# Final mu: 34.133103571
# Final std: 5.01139954994
# Real Value: [ 25.10382116]
#
#
# ------------------------- Iteration: 21900 -------------------------
# Average Loss(NLL): [ 6.73048666  7.45626319  6.7008712   6.87853813  6.82796495]
# mu: [ 28.84498115  20.71374892  29.8280839   32.06842942  28.95242993]
# std: [ 2.96970001  6.68437849  4.78933962  3.8706778   4.21722449]
# Final mu: 28.0815346664
# Final std: 6.06261126792
# Real Value: [ 31.87516496]
#
#
# ------------------------- Iteration: 22000 -------------------------
# Average Loss(NLL): [ 6.71869067  7.45005059  6.68464288  6.87179223  6.81277254]
# mu: [ 64.50796966  72.9579284   63.61807328  61.02827931  63.72169061]
# std: [ 3.50874893  7.3592487   2.81143464  3.79032785  2.36254436]
# Final mu: 65.1667882539
# Final std: 5.95100351945
# Real Value: [ 65.90907927]
#
#
# ------------------------- Iteration: 22100 -------------------------
# Average Loss(NLL): [ 6.72059597  7.44845974  6.74194355  6.88249744  6.80972005]
# mu: [ 9.61693412  1.26588676  2.98373078  9.68225429  9.0485842 ]
# std: [ 2.61378715  6.78269065  6.63688982  4.57031422  2.13070449]
# Final mu: 6.51947803159
# Final std: 6.13853812854
# Real Value: [ 8.53640236]
#
#
# ------------------------- Iteration: 22200 -------------------------
# Average Loss(NLL): [ 6.73576571  7.44710798  6.7814296   6.89398699  6.80241747]
# mu: [ 35.86242135  46.83724206  40.25643522  41.1641803   39.16648994]
# std: [ 3.34931108  7.30281911  3.95247504  3.702325    3.69777945]
# Final mu: 40.6573537749
# Final std: 5.85447817873
# Real Value: [ 33.4195912]
#
#
# ------------------------- Iteration: 22300 -------------------------
# Average Loss(NLL): [ 6.75592678  7.45661107  6.6774039   6.89001807  6.79061739]
# mu: [ 26.81275805  20.83609297  29.25644602  23.43815143  24.42624966]
# std: [ 2.72293311  6.32906833  4.30386028  4.19944608  5.39683406]
# Final mu: 24.9539396258
# Final std: 5.55437391788
# Real Value: [ 26.85991653]
#
#
# ------------------------- Iteration: 22400 -------------------------
# Average Loss(NLL): [ 6.72526336  7.44675958  6.75336548  6.89142462  6.7905458 ]
# mu: [ 41.04575405  46.3132293   40.59721184  38.27239696  38.17915932]
# std: [ 3.1670603   6.59143307  4.16609801  4.24177375  2.95403937]
# Final mu: 40.8815502942
# Final std: 5.31552768278
# Real Value: [ 42.6440906]
#
#
# ------------------------- Iteration: 22500 -------------------------
# Average Loss(NLL): [ 6.78144367  7.43710886  6.71652961  6.87929523  6.78250247]
# mu: [ 32.25308202  23.53450808  22.24472978  31.89651221  32.93936099]
# std: [ 3.67270139  6.36836028  4.72529425  3.8873039   2.06353597]
# Final mu: 28.5736386142
# Final std: 6.40046426921
# Real Value: [ 31.4201108]
#
#
# ------------------------- Iteration: 22600 -------------------------
# Average Loss(NLL): [ 6.77780767  7.43238062  6.69782894  6.87221065  6.77923531]
# mu: [ 30.6196928   41.2841405   31.93121656  29.77256535  29.14274088]
# std: [ 3.85809448  6.02467182  7.08377957  3.30935071  5.28964782]
# Final mu: 32.5500712191
# Final std: 6.92836805957
# Real Value: [ 32.96384756]
#
#
# ------------------------- Iteration: 22700 -------------------------
# Average Loss(NLL): [ 6.79520069  7.42466149  6.73481048  6.88336325  6.77577533]
# mu: [  8.58507216   2.87810383  12.69083725  13.54324865  12.73671164]
# std: [ 3.30307808  6.49070123  5.77635146  4.70198304  2.74306144]
# Final mu: 10.0867947083
# Final std: 6.26113983108
# Real Value: [ 9.73815902]
#
#
# ------------------------- Iteration: 22800 -------------------------
# Average Loss(NLL): [ 7.05766317  7.42501454  6.68812804  6.87402907  6.77823393]
# mu: [ 31.28799734  40.16084839  33.89703289  34.85805487  35.07658131]
# std: [ 6.37472372  6.38217433  2.9050907   2.96823557  3.93672231]
# Final mu: 35.0561029605
# Final std: 5.58134643823
# Real Value: [ 33.30651713]
#
#
# ------------------------- Iteration: 22900 -------------------------
# Average Loss(NLL): [ 6.86954353  7.41346928  6.68494852  6.88946519  6.77081348]
# mu: [ 35.30944608  26.56725657  34.52578833  27.18094573  31.44197528]
# std: [ 5.03514568  6.42866802  6.78463664  4.11214018  3.15316872]
# Final mu: 31.0050823997
# Final std: 6.40306239853
# Real Value: [ 33.76226077]
#
#
# ------------------------- Iteration: 23000 -------------------------
# Average Loss(NLL): [ 6.96712484  7.44161275  6.71233092  6.88704444  6.77886672]
# mu: [ 34.10732541  39.20749313  33.28150415  35.17806221  36.10202383]
# std: [ 3.17168683  5.98060895  3.9530395   2.8175879   2.17013201]
# Final mu: 35.5752817449
# Final std: 4.36226060914
# Real Value: [ 33.39959639]
#
#
# ------------------------- Iteration: 23100 -------------------------
# Average Loss(NLL): [ 6.7555579   7.41707276  6.6797519   6.88162588  6.68176642]
# mu: [ 38.67548411  32.33616846  36.997136    41.2659561   38.37978697]
# std: [ 1.29115176  6.9935258   3.06978428  3.84573005  3.34668807]
# Final mu: 37.5309063278
# Final std: 5.08412190947
# Real Value: [ 33.4195912]
#
#
# ------------------------- Iteration: 23200 -------------------------
# Average Loss(NLL): [ 6.78004672  7.41580562  6.63387565  6.87972785  6.68600547]
# mu: [ 33.39023377  42.20643596  35.90317029  31.68027642  34.77039752]
# std: [ 4.10887349  5.60058159  4.45754958  2.94148522  0.63752491]
# Final mu: 35.5901027943
# Final std: 5.32634650931
# Real Value: [ 35.22532884]
#
#
# ------------------------- Iteration: 23300 -------------------------
# Average Loss(NLL): [ 6.79299738  7.39857909  6.6999556   6.88194521  6.69017468]
# mu: [ 38.28301239  28.14609155  36.76402971  38.00112686  35.84904113]
# std: [ 2.56126719  6.03761771  1.38613967  3.47155815  2.27299843]
# Final mu: 35.408660327
# Final std: 5.136364228
# Real Value: [ 33.71882378]
#
#
# ------------------------- Iteration: 23400 -------------------------
# Average Loss(NLL): [ 6.85463283  7.4029207   6.62653509  6.87236885  6.75699039]
# mu: [ 30.68659823  39.6000746   30.93038547  36.95177161  35.39788389]
# std: [ 5.36865823  6.23212528  2.5907234   2.98345858  5.04816493]
# Final mu: 34.7133427587
# Final std: 5.80764090438
# Real Value: [ 33.30651713]
#
#
# ------------------------- Iteration: 23500 -------------------------
# Average Loss(NLL): [ 6.9308309   7.39678904  6.6755199   6.87606758  6.85480714]
# mu: [ 49.27672688  37.12671909  45.89852228  39.37647811  50.67775384]
# std: [ 4.34852386  6.9385613   3.61561706  5.32251011  4.3512428 ]
# Final mu: 44.4712400394
# Final std: 7.36121791539
# Real Value: [ 41.05346947]
#
#
# ------------------------- Iteration: 23600 -------------------------
# Average Loss(NLL): [ 6.73494871  7.39339715  6.5702695   6.91942294  6.81913744]
# mu: [ 49.77687291  58.45397521  47.33065582  43.49417302  43.74590183]
# std: [ 4.9780939   7.21949646  2.65418428  6.78974443  4.1618668 ]
# Final mu: 48.5603157584
# Final std: 7.70830672379
# Real Value: [ 46.23419213]
#
#
# ------------------------- Iteration: 23700 -------------------------
# Average Loss(NLL): [ 8.19682035  7.38697482  6.65417056  7.25939357  6.80008558]
# mu: [ 35.10247748  26.09458889  34.79069643  37.39922128  34.18530211]
# std: [ 5.06912273  5.19768252  4.66232094  5.02966559  3.96985154]
# Final mu: 33.5144572397
# Final std: 6.1685147032
# Real Value: [ 32.72046253]
#
#
# ------------------------- Iteration: 23800 -------------------------
# Average Loss(NLL): [ 6.77035707  7.38045897  6.63360954  7.24429633  6.79137408]
# mu: [ 58.34102362  61.16978372  56.9918512   49.73471835  58.29378237]
# std: [ 2.33035339  5.80983034  1.18757055  5.14263502  2.92024845]
# Final mu: 56.9062318524
# Final std: 5.46203772233
# Real Value: [ 56.61907964]
#
#
# ------------------------- Iteration: 23900 -------------------------
# Average Loss(NLL): [ 6.76044487  7.37509794  6.70951409  7.2335842   6.77791458]
# mu: [ 33.53854362  24.46240573  25.39636618  37.14631011  31.35134649]
# std: [ 4.97376686  6.29468448  5.25269952  5.59075489  4.94328182]
# Final mu: 30.3789944267
# Final std: 7.26914333839
# Real Value: [ 27.68108245]
#
#
# ------------------------- Iteration: 24000 -------------------------
# Average Loss(NLL): [ 6.95823978  7.36970465  6.73387533  7.22401658  6.78254426]
# mu: [ 33.22314125  48.40284337  41.7810348   33.39790825  41.84444787]
# std: [ 4.24713472  4.84240658  3.6035202   4.73660867  4.08248683]
# Final mu: 39.7298751082
# Final std: 7.20978523119
# Real Value: [ 36.80491836]
#
#
# ------------------------- Iteration: 24100 -------------------------
# Average Loss(NLL): [ 6.86014861  7.37374275  6.65550366  7.21203596  6.77384122]
# mu: [ 42.29969865  28.16207243  44.30304137  50.91611022  41.15539432]
# std: [ 6.20873172  5.09033017  4.02855621  6.12369155  3.89807639]
# Final mu: 41.3672633977
# Final std: 9.03852127634
# Real Value: [ 23.8903434]
#
#
# ------------------------- Iteration: 24200 -------------------------
# Average Loss(NLL): [ 6.78655815  7.36439694  6.66029208  7.20484362  6.77050235]
# mu: [ 40.11054769  49.12917293  43.61464341  37.39949056  39.76725109]
# std: [ 5.59418897  6.17858518  3.80139645  6.32041201  2.52157012]
# Final mu: 42.0042211372
# Final std: 6.53266223751
# Real Value: [ 40.8686899]
#
#
# ------------------------- Iteration: 24300 -------------------------
# Average Loss(NLL): [ 6.83875983  7.36491314  6.58480869  7.19474295  6.77418625]
# mu: [ 35.31400237  27.83518458  38.62407941  43.72866166  31.57751149]
# std: [ 4.38871819  6.04087218  3.85707604  5.73477768  4.97947755]
# Final mu: 35.4158879012
# Final std: 7.48222117549
# Real Value: [ 39.0560575]
#
#
# ------------------------- Iteration: 24400 -------------------------
# Average Loss(NLL): [ 6.90334134  7.36161671  6.61584388  7.18661537  6.74593941]
# mu: [ 27.43184766  32.98473543  29.290386    25.76390833  27.6444054 ]
# std: [ 4.84012467  6.13741622  3.16424302  5.183487    2.4098545 ]
# Final mu: 28.6230565652
# Final std: 5.17308595106
# Real Value: [ 26.14768782]
#
#
# ------------------------- Iteration: 24500 -------------------------
# Average Loss(NLL): [ 6.94042839  7.35667696  6.53235131  7.17371095  6.74676376]
# mu: [ 39.79570129  31.79359397  38.39328008  41.40555779  36.62966819]
# std: [ 4.27075622  6.22170831  2.66679789  5.11345937  2.17487724]
# Final mu: 37.6035602649
# Final std: 5.46858081511
# Real Value: [ 42.6440906]
#
#
# ------------------------- Iteration: 24600 -------------------------
# Average Loss(NLL): [ 6.94405766  7.35726371  6.60008397  7.17947738  6.70070583]
# mu: [ 34.8735981   39.08738142  29.70284617  26.64266912  33.45655947]
# std: [ 4.20633046  5.85853785  4.29684933  5.24465746  4.57871577]
# Final mu: 32.7526108532
# Final std: 6.49161870575
# Real Value: [ 27.68108245]
#
#
# ------------------------- Iteration: 24700 -------------------------
# Average Loss(NLL): [ 30.00004506   7.3517005    6.56038266   7.15931571   6.78972749]
# mu: [ 48.26654558  42.71133418  50.62666904  52.02627355  43.88629676]
# std: [ 3.8628543   3.74948791  3.03796465  4.43862618  3.28878392]
# Final mu: 47.5034238226
# Final std: 5.20707116719
# Real Value: [ 45.30477848]
#
#
# ------------------------- Iteration: 24800 -------------------------
# Average Loss(NLL): [ 6.93023364  7.34723392  6.50800463  7.15860128  6.75854793]
# mu: [  8.17660214  18.26994613   8.88600302   7.67466669  12.56703539]
# std: [ 7.34607433  5.38922621  3.61180663  4.89148597  2.48661513]
# Final mu: 11.1148506735
# Final std: 6.4016211656
# Real Value: [ 10.53588276]
#
#
# ------------------------- Iteration: 24900 -------------------------
# Average Loss(NLL): [ 6.80199902  7.34341883  6.48938951  7.15546156  6.7666351 ]
# mu: [ 34.50815776  29.57448761  36.82316776  41.10487302  38.10161164]
# std: [ 4.45577477  6.67892907  2.97957457  5.20907531  2.8514466 ]
# Final mu: 36.0224595588
# Final std: 6.05424621303
# Real Value: [ 40.06200298]

# %% [markdown]
# ## Testing with Known and Unknown Data

# %%
# Get Unknown dataset and test 
x_sample = np.random.randint(0, 50, size = (test_size,num_data))

out_mu_sample  = np.zeros([test_size, len(networks)])
out_sig_sample = np.zeros([test_size, len(networks)])

for i in range(len(networks)):
    mu_sample, sig_sample = sess.run([output_mu_list[i], output_sig_list[i]], 
                                      feed_dict = {x_list[i]: x_sample})

    out_mu_sample[:,i]  = np.reshape(mu_sample, (test_size))
    out_sig_sample[:,i] = np.reshape(sig_sample, (test_size))

out_mu_sample_final  = np.mean(out_mu_sample, axis = 1)
out_sig_sample_final = np.sqrt(np.mean(out_sig_sample + np.square(out_mu_sample), axis = 1) - np.square(out_mu_sample_final))

# Plot mean and variable vs real data 
plt.figure(1)
plt.hold
plt.plot(batch_y_test, 'bo')
plt.plot(out_mu_final, 'ro')
plt.vlines(x = np.arange(0, test_size), ymin = out_mu_final - out_sig_final, ymax = out_mu_final + out_sig_final, color = 'g', linewidth=2.0)
plt.legend(['Real data', 'Mu', 'mu+-sig'], loc = 'best')
plt.title('Ground Truth vs Prediction')
plt.xlim([-1, 10])

# Plot comparison of known sig and unknown sig
plt.figure(2)
plt.hold
plt.plot(out_sig_sample_final, 'bo')
plt.plot(out_sig_final, 'ro')
plt.legend(['Unknown Sig', 'Known Sig'], loc = 'best')
plt.title('Unknown Sigma vs Known Sigma')
plt.xlim([-1, 10])

plt.show()
